# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
import glob

# Define the features and target columns
features = ['time']
# , 'x0', 'y0', 'z0', 'x1', 'y1', 'z1', 'x2', 'y2', 'z2', 'x3', 'y3', 'z3', 
            # 'amp0', 'phase0', 'amp1', 'phase1', 'amp2', 'phase2', 'amp3', 'phase3'

# Define dropping_status columns
dropping_status_columns = ['drop_0', 'drop_1', 'drop_2', 'drop_3']

# Define the combined features list
all_features = features + dropping_status_columns

# File pattern to match different shots (feature files)
feature_file_pattern = 'C:/Users/weicheng/Desktop/formal_dataset/p4_x_r1_240813/4a-240702-gspat-crossing-0.50v-1*_pre_process_df2.csv'
feature_files = glob.glob(feature_file_pattern)

# Corresponding label file pattern
label_file_pattern = 'C:/Users/weicheng/Desktop/formal_dataset/p4_x_r1_240813/4a-240702-gspat-crossing-0.50v-1*_pre_process_df_labels.csv'
label_files = glob.glob(label_file_pattern)

# Initialize the scaler
scaler = MinMaxScaler(feature_range=(0, 1))

# Function to preprocess and create sequences for each shot
def preprocess_and_create_sequences(feature_file, label_file, time_steps=10):
    print(f"Processing: {feature_file}")
    
    # Read the feature data
    data = pd.read_csv(feature_file)
    
    # Read the corresponding label data
    labels = pd.read_csv(label_file)
    
    # Combine feature data with dropping status columns
    data_combined = pd.concat([data, labels[dropping_status_columns]], axis=1)

    # Handle missing values after combining the data
    data_combined.interpolate(method='linear', axis=0, inplace=True)
    data_combined.fillna(method='bfill', inplace=True)
    data_combined.fillna(method='ffill', inplace=True)

    # Scale the features including the dropping status columns
    scaled_data = scaler.fit_transform(data_combined[all_features])

    # Create sequences for time series data
    X, y = create_dataset(scaled_data, time_steps)
    return X, y, data_combined

# Convert the data to a supervised learning problem
def create_dataset(data, time_steps=1):
    X, y = [], []
    for i in range(len(data) - time_steps):
        X.append(data[i:(i + time_steps), :])
        y.append(data[i + time_steps, :])  # Predicting the next time step
    return np.array(X), np.array(y)

# Define the number of time steps
time_steps = 10

# Prepare lists to hold model inputs and outputs
X_train_list, y_train_list = [], []
X_test_list, y_test_list = [], []

# Split files into training and testing sets (80% training, 20% testing)
train_files = feature_files[:int(len(feature_files) * 0.8)]
test_files = feature_files[int(len(feature_files) * 0.8):]
train_label_files = label_files[:int(len(label_files) * 0.8)]
test_label_files = label_files[int(len(label_files) * 0.8):]

# Process each training file separately
for feature_file, label_file in zip(train_files, train_label_files):
    X, y, _ = preprocess_and_create_sequences(feature_file, label_file, time_steps)
    X_train_list.append(X)
    y_train_list.append(y)

# Process each testing file separately
for feature_file, label_file in zip(test_files, test_label_files):
    X, y, original_data_combined = preprocess_and_create_sequences(feature_file, label_file, time_steps)
    X_test_list.append(X)
    y_test_list.append(y)

# Train the model on each shot separately.
for i, (X_train, y_train) in enumerate(zip(X_train_list, y_train_list)):
    print(f"Training on shot {i + 1}/{len(X_train_list)}")
    
    # Build the LSTM model
    model = Sequential()
    model.add(LSTM(50, return_sequences=True, input_shape=(time_steps, len(all_features))))
    model.add(LSTM(50))
    model.add(Dense(len(all_features)))  # Output layer predicting the same number of features

    model.compile(optimizer='adam', loss='mean_squared_error')

    # Train the model on the current shot's data
    model.fit(X_train, y_train, epochs=100, batch_size=32, validation_split=0.2)

# Predict back the data with dropping_status_columns set to 0
for i, (X_test, y_test) in enumerate(zip(X_test_list, y_test_list)):
    print(f"Predicting back on shot {i + 1}/{len(X_test_list)}")
    
    # Set all dropping status columns to 0
    X_test[:, :, -len(dropping_status_columns):] = 0

    # Predict sequentially for each time step
    predicted_sequences = []
    current_input = X_test[0]  # Start with the first time step

    for _ in range(len(X_test)):
        predicted_output = model.predict(current_input[np.newaxis, :, :])
        predicted_sequences.append(predicted_output[0])

        # Shift the window by one time step and add the predicted values to the end
        current_input = np.roll(current_input, -1, axis=0)
        current_input[-1] = predicted_output[0]

    predicted_sequences = np.array(predicted_sequences)

    # Check the shape of the predicted_sequences
    print(f"Shape of predicted_sequences: {predicted_sequences.shape}")

    # Ensure that the shape matches the expected output before inverse transforming
    if predicted_sequences.shape[-1] != len(all_features):
        raise ValueError(f"Unexpected shape for predicted sequences: {predicted_sequences.shape}")

    # Inverse transform the predictions to the original scale
    scaled_predictions = np.concatenate((predicted_sequences, np.zeros((predicted_sequences.shape[0], len(all_features) - predicted_sequences.shape[-1]))), axis=1)
    predictions = scaler.inverse_transform(scaled_predictions)[:, :len(all_features)]

    # Save predictions to CSV
    output_df = pd.DataFrame(predictions, columns=all_features)
    
    # Separate out the original feature columns
    output_df_1 = output_df[features]

    # Apply the clipping operation on the dropping status columns
    output_df_2 = output_df[dropping_status_columns].applymap(lambda x: 1 if abs(x) > 0.5 else 0)
    
    output_df_1.to_csv(f'back_predictions_shot_df_{i + 1}.csv', index=False)
    output_df_2.to_csv(f'back_predictions_shot_df2_{i + 1}.csv', index=False)

    print(f"Back prediction for shot {i + 1} completed.")
# Out:
# WARNING:tensorflow:From c:\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# Processing: C:/Users/weicheng/Desktop/formal_dataset/p4_x_r1_240813\4a-240702-gspat-crossing-0.50v-1_001_c_pre_process_df2.csv
# Processing: C:/Users/weicheng/Desktop/formal_dataset/p4_x_r1_240813\4a-240702-gspat-crossing-0.50v-1_002_c_pre_process_df2.csv
# Processing: C:/Users/weicheng/Desktop/formal_dataset/p4_x_r1_240813\4a-240702-gspat-crossing-0.50v-1_003_c_pre_process_df2.csv
# Processing: C:/Users/weicheng/Desktop/formal_dataset/p4_x_r1_240813\4a-240702-gspat-crossing-0.50v-1_004_c_pre_process_df2.csv
# Processing: C:/Users/weicheng/Desktop/formal_dataset/p4_x_r1_240813\4a-240702-gspat-crossing-0.50v-1_005_c_pre_process_df2.csv
# Processing: C:/Users/weicheng/Desktop/formal_dataset/p4_x_r1_240813\4a-240702-gspat-crossing-0.50v-1_006_c_pre_process_df2.csv
# Processing: C:/Users/weicheng/Desktop/formal_dataset/p4_x_r1_240813\4a-240702-gspat-crossing-0.50v-1_007_c_pre_process_df2.csv
# Processing: C:/Users/weicheng/Desktop/formal_dataset/p4_x_r1_240813\4a-240702-gspat-crossing-0.50v-1_008_c_pre_process_df2.csv
# Processing: C:/Users/weicheng/Desktop/formal_dataset/p4_x_r1_240813\4a-240702-gspat-crossing-0.50v-1_009_c_pre_process_df2.csv
# Processing: C:/Users/weicheng/Desktop/formal_dataset/p4_x_r1_240813\4a-240702-gspat-crossing-0.50v-1_010_c_pre_process_df2.csv
# Processing: C:/Users/weicheng/Desktop/formal_dataset/p4_x_r1_240813\4a-240702-gspat-crossing-0.50v-1_011_c_pre_process_df2.csv
# Processing: C:/Users/weicheng/Desktop/formal_dataset/p4_x_r1_240813\4a-240702-gspat-crossing-0.50v-1_013_c_pre_process_df2.csv
# Processing: C:/Users/weicheng/Desktop/formal_dataset/p4_x_r1_240813\4a-240702-gspat-crossing-0.50v-1_014_c_pre_process_df2.csv
# Processing: C:/Users/weicheng/Desktop/formal_dataset/p4_x_r1_240813\4a-240702-gspat-crossing-0.50v-1_015_c_pre_process_df2.csv
# Processing: C:/Users/weicheng/Desktop/formal_dataset/p4_x_r1_240813\4a-240702-gspat-crossing-0.50v-1_016_c_pre_process_df2.csv
# Processing: C:/Users/weicheng/Desktop/formal_dataset/p4_x_r1_240813\4a-240702-gspat-crossing-0.50v-1_017_c_pre_process_df2.csv
# Processing: C:/Users/weicheng/Desktop/formal_dataset/p4_x_r1_240813\4a-240702-gspat-crossing-0.50v-1_018_c_pre_process_df2.csv
# Processing: C:/Users/weicheng/Desktop/formal_dataset/p4_x_r1_240813\4a-240702-gspat-crossing-0.50v-1_019_c_pre_process_df2.csv
# Processing: C:/Users/weicheng/Desktop/formal_dataset/p4_x_r1_240813\4a-240702-gspat-crossing-0.50v-1_021_c_pre_process_df2.csv
# Processing: C:/Users/weicheng/Desktop/formal_dataset/p4_x_r1_240813\4a-240702-gspat-crossing-0.50v-1_022_c_pre_process_df2.csv
# Processing: C:/Users/weicheng/Desktop/formal_dataset/p4_x_r1_240813\4a-240702-gspat-crossing-0.50v-1_c_pre_process_df2.csv
# Training on shot 1/16
# C:\Users\weicheng\AppData\Local\Temp\ipykernel_26120\3814716982.py:45: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data_combined.fillna(method='bfill', inplace=True)
# C:\Users\weicheng\AppData\Local\Temp\ipykernel_26120\3814716982.py:46: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data_combined.fillna(method='ffill', inplace=True)
# C:\Users\weicheng\AppData\Local\Temp\ipykernel_26120\3814716982.py:45: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data_combined.fillna(method='bfill', inplace=True)
# C:\Users\weicheng\AppData\Local\Temp\ipykernel_26120\3814716982.py:46: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data_combined.fillna(method='ffill', inplace=True)
# C:\Users\weicheng\AppData\Local\Temp\ipykernel_26120\3814716982.py:45: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data_combined.fillna(method='bfill', inplace=True)
# C:\Users\weicheng\AppData\Local\Temp\ipykernel_26120\3814716982.py:46: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data_combined.fillna(method='ffill', inplace=True)
# C:\Users\weicheng\AppData\Local\Temp\ipykernel_26120\3814716982.py:45: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data_combined.fillna(method='bfill', inplace=True)
# C:\Users\weicheng\AppData\Local\Temp\ipykernel_26120\3814716982.py:46: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data_combined.fillna(method='ffill', inplace=True)
# C:\Users\weicheng\AppData\Local\Temp\ipykernel_26120\3814716982.py:45: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data_combined.fillna(method='bfill', inplace=True)
# C:\Users\weicheng\AppData\Local\Temp\ipykernel_26120\3814716982.py:46: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data_combined.fillna(method='ffill', inplace=True)
# C:\Users\weicheng\AppData\Local\Temp\ipykernel_26120\3814716982.py:45: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data_combined.fillna(method='bfill', inplace=True)
# C:\Users\weicheng\AppData\Local\Temp\ipykernel_26120\3814716982.py:46: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data_combined.fillna(method='ffill', inplace=True)
# C:\Users\weicheng\AppData\Local\Temp\ipykernel_26120\3814716982.py:45: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data_combined.fillna(method='bfill', inplace=True)
# C:\Users\weicheng\AppData\Local\Temp\ipykernel_26120\3814716982.py:46: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data_combined.fillna(method='ffill', inplace=True)
# C:\Users\weicheng\AppData\Local\Temp\ipykernel_26120\3814716982.py:45: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data_combined.fillna(method='bfill', inplace=True)
# C:\Users\weicheng\AppData\Local\Temp\ipykernel_26120\3814716982.py:46: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data_combined.fillna(method='ffill', inplace=True)
# C:\Users\weicheng\AppData\Local\Temp\ipykernel_26120\3814716982.py:45: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data_combined.fillna(method='bfill', inplace=True)
# C:\Users\weicheng\AppData\Local\Temp\ipykernel_26120\3814716982.py:46: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data_combined.fillna(method='ffill', inplace=True)
# C:\Users\weicheng\AppData\Local\Temp\ipykernel_26120\3814716982.py:45: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data_combined.fillna(method='bfill', inplace=True)
# C:\Users\weicheng\AppData\Local\Temp\ipykernel_26120\3814716982.py:46: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data_combined.fillna(method='ffill', inplace=True)
# C:\Users\weicheng\AppData\Local\Temp\ipykernel_26120\3814716982.py:45: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data_combined.fillna(method='bfill', inplace=True)
# C:\Users\weicheng\AppData\Local\Temp\ipykernel_26120\3814716982.py:46: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data_combined.fillna(method='ffill', inplace=True)
# C:\Users\weicheng\AppData\Local\Temp\ipykernel_26120\3814716982.py:45: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data_combined.fillna(method='bfill', inplace=True)
# C:\Users\weicheng\AppData\Local\Temp\ipykernel_26120\3814716982.py:46: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data_combined.fillna(method='ffill', inplace=True)
# C:\Users\weicheng\AppData\Local\Temp\ipykernel_26120\3814716982.py:45: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data_combined.fillna(method='bfill', inplace=True)
# C:\Users\weicheng\AppData\Local\Temp\ipykernel_26120\3814716982.py:46: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data_combined.fillna(method='ffill', inplace=True)
# C:\Users\weicheng\AppData\Local\Temp\ipykernel_26120\3814716982.py:45: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data_combined.fillna(method='bfill', inplace=True)
# C:\Users\weicheng\AppData\Local\Temp\ipykernel_26120\3814716982.py:46: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data_combined.fillna(method='ffill', inplace=True)
# C:\Users\weicheng\AppData\Local\Temp\ipykernel_26120\3814716982.py:45: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data_combined.fillna(method='bfill', inplace=True)
# C:\Users\weicheng\AppData\Local\Temp\ipykernel_26120\3814716982.py:46: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data_combined.fillna(method='ffill', inplace=True)
# C:\Users\weicheng\AppData\Local\Temp\ipykernel_26120\3814716982.py:45: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data_combined.fillna(method='bfill', inplace=True)
# C:\Users\weicheng\AppData\Local\Temp\ipykernel_26120\3814716982.py:46: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data_combined.fillna(method='ffill', inplace=True)
# C:\Users\weicheng\AppData\Local\Temp\ipykernel_26120\3814716982.py:45: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data_combined.fillna(method='bfill', inplace=True)
# C:\Users\weicheng\AppData\Local\Temp\ipykernel_26120\3814716982.py:46: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data_combined.fillna(method='ffill', inplace=True)
# C:\Users\weicheng\AppData\Local\Temp\ipykernel_26120\3814716982.py:45: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data_combined.fillna(method='bfill', inplace=True)
# C:\Users\weicheng\AppData\Local\Temp\ipykernel_26120\3814716982.py:46: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data_combined.fillna(method='ffill', inplace=True)
# C:\Users\weicheng\AppData\Local\Temp\ipykernel_26120\3814716982.py:45: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data_combined.fillna(method='bfill', inplace=True)
# C:\Users\weicheng\AppData\Local\Temp\ipykernel_26120\3814716982.py:46: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data_combined.fillna(method='ffill', inplace=True)
# C:\Users\weicheng\AppData\Local\Temp\ipykernel_26120\3814716982.py:45: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data_combined.fillna(method='bfill', inplace=True)
# C:\Users\weicheng\AppData\Local\Temp\ipykernel_26120\3814716982.py:46: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data_combined.fillna(method='ffill', inplace=True)
# C:\Users\weicheng\AppData\Local\Temp\ipykernel_26120\3814716982.py:45: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data_combined.fillna(method='bfill', inplace=True)
# C:\Users\weicheng\AppData\Local\Temp\ipykernel_26120\3814716982.py:46: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data_combined.fillna(method='ffill', inplace=True)
# WARNING:tensorflow:From c:\Python311\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From c:\Python311\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Epoch 1/100
# WARNING:tensorflow:From c:\Python311\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 1/1 [==============================] - 4s 4s/step - loss: 0.1686 - val_loss: 0.6516
# Epoch 2/100
# 1/1 [==============================] - 0s 36ms/step - loss: 0.1560 - val_loss: 0.6008
# Epoch 3/100
# 1/1 [==============================] - 0s 36ms/step - loss: 0.1440 - val_loss: 0.5518
# Epoch 4/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.1324 - val_loss: 0.5037
# Epoch 5/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.1211 - val_loss: 0.4563
# Epoch 6/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.1101 - val_loss: 0.4095
# Epoch 7/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0993 - val_loss: 0.3634
# Epoch 8/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0888 - val_loss: 0.3185
# Epoch 9/100
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0787 - val_loss: 0.2756
# Epoch 10/100
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0693 - val_loss: 0.2359
# Epoch 11/100
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0608 - val_loss: 0.2009
# Epoch 12/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0536 - val_loss: 0.1719
# Epoch 13/100
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0481 - val_loss: 0.1500
# Epoch 14/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0444 - val_loss: 0.1350
# Epoch 15/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0424 - val_loss: 0.1260
# Epoch 16/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0415 - val_loss: 0.1213
# Epoch 17/100
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0411 - val_loss: 0.1195
# Epoch 18/100
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0404 - val_loss: 0.1197
# Epoch 19/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0393 - val_loss: 0.1218
# Epoch 20/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0378 - val_loss: 0.1257
# Epoch 21/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0361 - val_loss: 0.1310
# Epoch 22/100
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0344 - val_loss: 0.1369
# Epoch 23/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0327 - val_loss: 0.1427
# Epoch 24/100
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0311 - val_loss: 0.1475
# Epoch 25/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0296 - val_loss: 0.1512
# Epoch 26/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0282 - val_loss: 0.1538
# Epoch 27/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0269 - val_loss: 0.1558
# Epoch 28/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0258 - val_loss: 0.1578
# Epoch 29/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0248 - val_loss: 0.1607
# Epoch 30/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0240 - val_loss: 0.1651
# Epoch 31/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0234 - val_loss: 0.1715
# Epoch 32/100
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0230 - val_loss: 0.1799
# Epoch 33/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0226 - val_loss: 0.1902
# Epoch 34/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0224 - val_loss: 0.2016
# Epoch 35/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0222 - val_loss: 0.2130
# Epoch 36/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0219 - val_loss: 0.2234
# Epoch 37/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0217 - val_loss: 0.2318
# Epoch 38/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0213 - val_loss: 0.2377
# Epoch 39/100
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0209 - val_loss: 0.2408
# Epoch 40/100
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0204 - val_loss: 0.2416
# Epoch 41/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0200 - val_loss: 0.2403
# Epoch 42/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0196 - val_loss: 0.2374
# Epoch 43/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0193 - val_loss: 0.2333
# Epoch 44/100
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0190 - val_loss: 0.2281
# Epoch 45/100
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0188 - val_loss: 0.2219
# Epoch 46/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0186 - val_loss: 0.2148
# Epoch 47/100
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0184 - val_loss: 0.2071
# Epoch 48/100
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0182 - val_loss: 0.1989
# Epoch 49/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0179 - val_loss: 0.1904
# Epoch 50/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0176 - val_loss: 0.1820
# Epoch 51/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0173 - val_loss: 0.1739
# Epoch 52/100
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0171 - val_loss: 0.1663
# Epoch 53/100
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0169 - val_loss: 0.1594
# Epoch 54/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0167 - val_loss: 0.1532
# Epoch 55/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0165 - val_loss: 0.1478
# Epoch 56/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0164 - val_loss: 0.1434
# Epoch 57/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0162 - val_loss: 0.1399
# Epoch 58/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0160 - val_loss: 0.1375
# Epoch 59/100
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0158 - val_loss: 0.1362
# Epoch 60/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0156 - val_loss: 0.1360
# Epoch 61/100
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0154 - val_loss: 0.1367
# Epoch 62/100
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0152 - val_loss: 0.1380
# Epoch 63/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0151 - val_loss: 0.1397
# Epoch 64/100
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0150 - val_loss: 0.1414
# Epoch 65/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0149 - val_loss: 0.1429
# Epoch 66/100
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0148 - val_loss: 0.1442
# Epoch 67/100
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0146 - val_loss: 0.1452
# Epoch 68/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0145 - val_loss: 0.1460
# Epoch 69/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0144 - val_loss: 0.1467
# Epoch 70/100
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0143 - val_loss: 0.1475
# Epoch 71/100
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0143 - val_loss: 0.1486
# Epoch 72/100
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0142 - val_loss: 0.1501
# Epoch 73/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0141 - val_loss: 0.1519
# Epoch 74/100
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0140 - val_loss: 0.1540
# Epoch 75/100
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0139 - val_loss: 0.1560
# Epoch 76/100
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0139 - val_loss: 0.1578
# Epoch 77/100
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0138 - val_loss: 0.1590
# Epoch 78/100
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0137 - val_loss: 0.1597
# Epoch 79/100
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0137 - val_loss: 0.1600
# Epoch 80/100
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0136 - val_loss: 0.1600
# Epoch 81/100
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0135 - val_loss: 0.1601
# Epoch 82/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0135 - val_loss: 0.1604
# Epoch 83/100
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0134 - val_loss: 0.1609
# Epoch 84/100
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0133 - val_loss: 0.1616
# Epoch 85/100
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0133 - val_loss: 0.1624
# Epoch 86/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0132 - val_loss: 0.1629
# Epoch 87/100
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0132 - val_loss: 0.1630
# Epoch 88/100
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0131 - val_loss: 0.1627
# Epoch 89/100
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0130 - val_loss: 0.1618
# Epoch 90/100
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0130 - val_loss: 0.1607
# Epoch 91/100
# 1/1 [==============================] - 0s 76ms/step - loss: 0.0129 - val_loss: 0.1593
# Epoch 92/100
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0128 - val_loss: 0.1580
# Epoch 93/100
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0128 - val_loss: 0.1569
# Epoch 94/100
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0127 - val_loss: 0.1560
# Epoch 95/100
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0127 - val_loss: 0.1552
# Epoch 96/100
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0126 - val_loss: 0.1546
# Epoch 97/100
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0125 - val_loss: 0.1539
# Epoch 98/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0125 - val_loss: 0.1530
# Epoch 99/100
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0124 - val_loss: 0.1520
# Epoch 100/100
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0124 - val_loss: 0.1508
# Training on shot 2/16
# Epoch 1/100
# 1/1 [==============================] - 4s 4s/step - loss: 0.1337 - val_loss: 0.4955
# Epoch 2/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.1226 - val_loss: 0.4671
# Epoch 3/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.1123 - val_loss: 0.4397
# Epoch 4/100
# 1/1 [==============================] - 0s 33ms/step - loss: 0.1026 - val_loss: 0.4128
# Epoch 5/100
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0932 - val_loss: 0.3865
# Epoch 6/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0842 - val_loss: 0.3604
# Epoch 7/100
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0755 - val_loss: 0.3345
# Epoch 8/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0669 - val_loss: 0.3087
# Epoch 9/100
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0587 - val_loss: 0.2833
# Epoch 10/100
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0508 - val_loss: 0.2585
# Epoch 11/100
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0435 - val_loss: 0.2350
# Epoch 12/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0371 - val_loss: 0.2141
# Epoch 13/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0320 - val_loss: 0.1970
# Epoch 14/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0285 - val_loss: 0.1852
# Epoch 15/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0270 - val_loss: 0.1787
# Epoch 16/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0274 - val_loss: 0.1755
# Epoch 17/100
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0288 - val_loss: 0.1726
# Epoch 18/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0300 - val_loss: 0.1683
# Epoch 19/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0302 - val_loss: 0.1627
# Epoch 20/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0293 - val_loss: 0.1568
# Epoch 21/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0277 - val_loss: 0.1519
# Epoch 22/100
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0258 - val_loss: 0.1485
# Epoch 23/100
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0241 - val_loss: 0.1470
# Epoch 24/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0227 - val_loss: 0.1469
# Epoch 25/100
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0217 - val_loss: 0.1480
# Epoch 26/100
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0209 - val_loss: 0.1498
# Epoch 27/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0204 - val_loss: 0.1519
# Epoch 28/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0201 - val_loss: 0.1542
# Epoch 29/100
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0197 - val_loss: 0.1566
# Epoch 30/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0194 - val_loss: 0.1592
# Epoch 31/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0190 - val_loss: 0.1621
# Epoch 32/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0186 - val_loss: 0.1655
# Epoch 33/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0181 - val_loss: 0.1698
# Epoch 34/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0176 - val_loss: 0.1753
# Epoch 35/100
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0171 - val_loss: 0.1823
# Epoch 36/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0165 - val_loss: 0.1910
# Epoch 37/100
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0160 - val_loss: 0.2013
# Epoch 38/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0156 - val_loss: 0.2131
# Epoch 39/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0153 - val_loss: 0.2257
# Epoch 40/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0150 - val_loss: 0.2381
# Epoch 41/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0149 - val_loss: 0.2495
# Epoch 42/100
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0148 - val_loss: 0.2586
# Epoch 43/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0147 - val_loss: 0.2648
# Epoch 44/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0145 - val_loss: 0.2680
# Epoch 45/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0144 - val_loss: 0.2684
# Epoch 46/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0143 - val_loss: 0.2666
# Epoch 47/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0141 - val_loss: 0.2635
# Epoch 48/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0140 - val_loss: 0.2597
# Epoch 49/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0139 - val_loss: 0.2559
# Epoch 50/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0137 - val_loss: 0.2525
# Epoch 51/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0136 - val_loss: 0.2497
# Epoch 52/100
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0135 - val_loss: 0.2476
# Epoch 53/100
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0133 - val_loss: 0.2462
# Epoch 54/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0132 - val_loss: 0.2452
# Epoch 55/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0130 - val_loss: 0.2445
# Epoch 56/100
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0129 - val_loss: 0.2438
# Epoch 57/100
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0128 - val_loss: 0.2429
# Epoch 58/100
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0127 - val_loss: 0.2417
# Epoch 59/100
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0126 - val_loss: 0.2399
# Epoch 60/100
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0125 - val_loss: 0.2375
# Epoch 61/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0124 - val_loss: 0.2346
# Epoch 62/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0123 - val_loss: 0.2314
# Epoch 63/100
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0122 - val_loss: 0.2279
# Epoch 64/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0121 - val_loss: 0.2244
# Epoch 65/100
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0120 - val_loss: 0.2210
# Epoch 66/100
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0119 - val_loss: 0.2178
# Epoch 67/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0118 - val_loss: 0.2149
# Epoch 68/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0117 - val_loss: 0.2122
# Epoch 69/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0116 - val_loss: 0.2098
# Epoch 70/100
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0115 - val_loss: 0.2076
# Epoch 71/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0115 - val_loss: 0.2057
# Epoch 72/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0114 - val_loss: 0.2040
# Epoch 73/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0113 - val_loss: 0.2025
# Epoch 74/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0112 - val_loss: 0.2011
# Epoch 75/100
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0112 - val_loss: 0.1999
# Epoch 76/100
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0111 - val_loss: 0.1989
# Epoch 77/100
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0110 - val_loss: 0.1979
# Epoch 78/100
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0110 - val_loss: 0.1971
# Epoch 79/100
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0109 - val_loss: 0.1963
# Epoch 80/100
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0108 - val_loss: 0.1957
# Epoch 81/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0108 - val_loss: 0.1952
# Epoch 82/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0107 - val_loss: 0.1948
# Epoch 83/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0106 - val_loss: 0.1945
# Epoch 84/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0106 - val_loss: 0.1943
# Epoch 85/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0105 - val_loss: 0.1940
# Epoch 86/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0105 - val_loss: 0.1937
# Epoch 87/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0104 - val_loss: 0.1934
# Epoch 88/100
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0104 - val_loss: 0.1929
# Epoch 89/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0103 - val_loss: 0.1922
# Epoch 90/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0103 - val_loss: 0.1914
# Epoch 91/100
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0102 - val_loss: 0.1904
# Epoch 92/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0101 - val_loss: 0.1893
# Epoch 93/100
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0101 - val_loss: 0.1882
# Epoch 94/100
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0100 - val_loss: 0.1871
# Epoch 95/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0100 - val_loss: 0.1860
# Epoch 96/100
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0099 - val_loss: 0.1851
# Epoch 97/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0099 - val_loss: 0.1844
# Epoch 98/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0098 - val_loss: 0.1839
# Epoch 99/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0098 - val_loss: 0.1836
# Epoch 100/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0098 - val_loss: 0.1833
# Training on shot 3/16
# Epoch 1/100
# 1/1 [==============================] - 4s 4s/step - loss: 0.2113 - val_loss: 0.7829
# Epoch 2/100
# 1/1 [==============================] - 0s 39ms/step - loss: 0.1956 - val_loss: 0.7139
# Epoch 3/100
# 1/1 [==============================] - 0s 36ms/step - loss: 0.1808 - val_loss: 0.6497
# Epoch 4/100
# 1/1 [==============================] - 0s 36ms/step - loss: 0.1668 - val_loss: 0.5887
# Epoch 5/100
# 1/1 [==============================] - 0s 39ms/step - loss: 0.1532 - val_loss: 0.5299
# Epoch 6/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.1398 - val_loss: 0.4725
# Epoch 7/100
# 1/1 [==============================] - 0s 37ms/step - loss: 0.1267 - val_loss: 0.4162
# Epoch 8/100
# 1/1 [==============================] - 0s 38ms/step - loss: 0.1136 - val_loss: 0.3612
# Epoch 9/100
# 1/1 [==============================] - 0s 36ms/step - loss: 0.1007 - val_loss: 0.3081
# Epoch 10/100
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0880 - val_loss: 0.2579
# Epoch 11/100
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0758 - val_loss: 0.2124
# Epoch 12/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0644 - val_loss: 0.1740
# Epoch 13/100
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0544 - val_loss: 0.1457
# Epoch 14/100
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0465 - val_loss: 0.1312
# Epoch 15/100
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0414 - val_loss: 0.1332
# Epoch 16/100
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0400 - val_loss: 0.1509
# Epoch 17/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0419 - val_loss: 0.1772
# Epoch 18/100
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0453 - val_loss: 0.2009
# Epoch 19/100
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0477 - val_loss: 0.2145
# Epoch 20/100
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0476 - val_loss: 0.2167
# Epoch 21/100
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0451 - val_loss: 0.2104
# Epoch 22/100
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0412 - val_loss: 0.1994
# Epoch 23/100
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0370 - val_loss: 0.1873
# Epoch 24/100
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0335 - val_loss: 0.1764
# Epoch 25/100
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0309 - val_loss: 0.1675
# Epoch 26/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0294 - val_loss: 0.1608
# Epoch 27/100
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0287 - val_loss: 0.1560
# Epoch 28/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0285 - val_loss: 0.1525
# Epoch 29/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0286 - val_loss: 0.1501
# Epoch 30/100
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0288 - val_loss: 0.1486
# Epoch 31/100
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0288 - val_loss: 0.1479
# Epoch 32/100
# 1/1 [==============================] - 0s 43ms/step - loss: 0.0286 - val_loss: 0.1484
# Epoch 33/100
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0282 - val_loss: 0.1503
# Epoch 34/100
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0276 - val_loss: 0.1539
# Epoch 35/100
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0268 - val_loss: 0.1594
# Epoch 36/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0260 - val_loss: 0.1667
# Epoch 37/100
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0252 - val_loss: 0.1755
# Epoch 38/100
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0246 - val_loss: 0.1852
# Epoch 39/100
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0241 - val_loss: 0.1947
# Epoch 40/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0238 - val_loss: 0.2031
# Epoch 41/100
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0236 - val_loss: 0.2094
# Epoch 42/100
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0235 - val_loss: 0.2129
# Epoch 43/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0233 - val_loss: 0.2133
# Epoch 44/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0231 - val_loss: 0.2107
# Epoch 45/100
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0227 - val_loss: 0.2057
# Epoch 46/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0223 - val_loss: 0.1990
# Epoch 47/100
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0218 - val_loss: 0.1915
# Epoch 48/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0213 - val_loss: 0.1838
# Epoch 49/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0209 - val_loss: 0.1765
# Epoch 50/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0205 - val_loss: 0.1700
# Epoch 51/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0201 - val_loss: 0.1645
# Epoch 52/100
# 1/1 [==============================] - 0s 80ms/step - loss: 0.0199 - val_loss: 0.1600
# Epoch 53/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0197 - val_loss: 0.1564
# Epoch 54/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0195 - val_loss: 0.1536
# Epoch 55/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0193 - val_loss: 0.1514
# Epoch 56/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0191 - val_loss: 0.1499
# Epoch 57/100
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0188 - val_loss: 0.1489
# Epoch 58/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0186 - val_loss: 0.1483
# Epoch 59/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0183 - val_loss: 0.1480
# Epoch 60/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0180 - val_loss: 0.1480
# Epoch 61/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0177 - val_loss: 0.1483
# Epoch 62/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0174 - val_loss: 0.1486
# Epoch 63/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0172 - val_loss: 0.1489
# Epoch 64/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0170 - val_loss: 0.1490
# Epoch 65/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0167 - val_loss: 0.1489
# Epoch 66/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0165 - val_loss: 0.1485
# Epoch 67/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0163 - val_loss: 0.1479
# Epoch 68/100
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0161 - val_loss: 0.1469
# Epoch 69/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0158 - val_loss: 0.1459
# Epoch 70/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0156 - val_loss: 0.1447
# Epoch 71/100
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0154 - val_loss: 0.1436
# Epoch 72/100
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0152 - val_loss: 0.1426
# Epoch 73/100
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0149 - val_loss: 0.1416
# Epoch 74/100
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0148 - val_loss: 0.1408
# Epoch 75/100
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0146 - val_loss: 0.1402
# Epoch 76/100
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0144 - val_loss: 0.1397
# Epoch 77/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0142 - val_loss: 0.1394
# Epoch 78/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0140 - val_loss: 0.1392
# Epoch 79/100
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0139 - val_loss: 0.1393
# Epoch 80/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0137 - val_loss: 0.1396
# Epoch 81/100
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0135 - val_loss: 0.1402
# Epoch 82/100
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0134 - val_loss: 0.1411
# Epoch 83/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0132 - val_loss: 0.1421
# Epoch 84/100
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0131 - val_loss: 0.1433
# Epoch 85/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0130 - val_loss: 0.1446
# Epoch 86/100
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0129 - val_loss: 0.1459
# Epoch 87/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0128 - val_loss: 0.1472
# Epoch 88/100
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0127 - val_loss: 0.1483
# Epoch 89/100
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0126 - val_loss: 0.1493
# Epoch 90/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0125 - val_loss: 0.1501
# Epoch 91/100
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0124 - val_loss: 0.1509
# Epoch 92/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0123 - val_loss: 0.1515
# Epoch 93/100
# 1/1 [==============================] - 0s 32ms/step - loss: 0.0122 - val_loss: 0.1521
# Epoch 94/100
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0122 - val_loss: 0.1527
# Epoch 95/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0121 - val_loss: 0.1533
# Epoch 96/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0120 - val_loss: 0.1540
# Epoch 97/100
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0120 - val_loss: 0.1548
# Epoch 98/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0119 - val_loss: 0.1556
# Epoch 99/100
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0119 - val_loss: 0.1564
# Epoch 100/100
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0118 - val_loss: 0.1571
# Training on shot 4/16
# Epoch 1/100
# 1/1 [==============================] - 4s 4s/step - loss: 0.1109 - val_loss: 0.4541
# Epoch 2/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.1026 - val_loss: 0.4295
# Epoch 3/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0948 - val_loss: 0.4056
# Epoch 4/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0874 - val_loss: 0.3822
# Epoch 5/100
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0803 - val_loss: 0.3589
# Epoch 6/100
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0734 - val_loss: 0.3354
# Epoch 7/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0666 - val_loss: 0.3116
# Epoch 8/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0599 - val_loss: 0.2872
# Epoch 9/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0533 - val_loss: 0.2623
# Epoch 10/100
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0468 - val_loss: 0.2371
# Epoch 11/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0406 - val_loss: 0.2118
# Epoch 12/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0348 - val_loss: 0.1873
# Epoch 13/100
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0298 - val_loss: 0.1643
# Epoch 14/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0260 - val_loss: 0.1442
# Epoch 15/100
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0238 - val_loss: 0.1283
# Epoch 16/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0235 - val_loss: 0.1178
# Epoch 17/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0248 - val_loss: 0.1123
# Epoch 18/100
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0266 - val_loss: 0.1102
# Epoch 19/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0277 - val_loss: 0.1098
# Epoch 20/100
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0274 - val_loss: 0.1102
# Epoch 21/100
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0259 - val_loss: 0.1115
# Epoch 22/100
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0239 - val_loss: 0.1137
# Epoch 23/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0219 - val_loss: 0.1170
# Epoch 24/100
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0202 - val_loss: 0.1210
# Epoch 25/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0190 - val_loss: 0.1254
# Epoch 26/100
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0182 - val_loss: 0.1298
# Epoch 27/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0178 - val_loss: 0.1341
# Epoch 28/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0176 - val_loss: 0.1381
# Epoch 29/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0174 - val_loss: 0.1421
# Epoch 30/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0172 - val_loss: 0.1465
# Epoch 31/100
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0169 - val_loss: 0.1518
# Epoch 32/100
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0165 - val_loss: 0.1590
# Epoch 33/100
# 1/1 [==============================] - 0s 50ms/step - loss: 0.0160 - val_loss: 0.1688
# Epoch 34/100
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0153 - val_loss: 0.1822
# Epoch 35/100
# 1/1 [==============================] - 0s 47ms/step - loss: 0.0146 - val_loss: 0.1998
# Epoch 36/100
# 1/1 [==============================] - 0s 44ms/step - loss: 0.0140 - val_loss: 0.2219
# Epoch 37/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0134 - val_loss: 0.2478
# Epoch 38/100
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0130 - val_loss: 0.2761
# Epoch 39/100
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0127 - val_loss: 0.3041
# Epoch 40/100
# ...
# Epoch 46/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0299 - val_loss: 0.2059
# Epoch 47/100
# 1/1 [==============================] - 0s 42ms/step - loss: 0.0295 - val_loss: 0.1987
# Epoch 48/100
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0290 - val_loss: 0.1905
# Epoch 49/100
# 1/1 [==============================] - 0s 97ms/step - loss: 0.0285 - val_loss: 0.1822
# Epoch 50/100
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0279 - val_loss: 0.1747
# Epoch 51/100
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0274 - val_loss: 0.1684
# Epoch 52/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0270 - val_loss: 0.1635
# Epoch 53/100
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0266 - val_loss: 0.1602
# Epoch 54/100
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0263 - val_loss: 0.1583
# Epoch 55/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0260 - val_loss: 0.1576
# Epoch 56/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0257 - val_loss: 0.1579
# Epoch 57/100
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0254 - val_loss: 0.1588
# Epoch 58/100
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0251 - val_loss: 0.1603
# Epoch 59/100
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0247 - val_loss: 0.1621
# Epoch 60/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0243 - val_loss: 0.1639
# Epoch 61/100
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0239 - val_loss: 0.1658
# Epoch 62/100
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0234 - val_loss: 0.1674
# Epoch 63/100
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0230 - val_loss: 0.1688
# Epoch 64/100
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0227 - val_loss: 0.1696
# Epoch 65/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0223 - val_loss: 0.1699
# Epoch 66/100
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0220 - val_loss: 0.1695
# Epoch 67/100
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0216 - val_loss: 0.1684
# Epoch 68/100
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0212 - val_loss: 0.1667
# Epoch 69/100
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0209 - val_loss: 0.1645
# Epoch 70/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0205 - val_loss: 0.1621
# Epoch 71/100
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0201 - val_loss: 0.1597
# Epoch 72/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0197 - val_loss: 0.1575
# Epoch 73/100
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0193 - val_loss: 0.1556
# Epoch 74/100
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0190 - val_loss: 0.1540
# Epoch 75/100
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0186 - val_loss: 0.1529
# Epoch 76/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0183 - val_loss: 0.1521
# Epoch 77/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0180 - val_loss: 0.1516
# Epoch 78/100
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0176 - val_loss: 0.1515
# Epoch 79/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0173 - val_loss: 0.1516
# Epoch 80/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0170 - val_loss: 0.1521
# Epoch 81/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0167 - val_loss: 0.1529
# Epoch 82/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0164 - val_loss: 0.1540
# Epoch 83/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0162 - val_loss: 0.1554
# Epoch 84/100
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0160 - val_loss: 0.1569
# Epoch 85/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0158 - val_loss: 0.1586
# Epoch 86/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0156 - val_loss: 0.1602
# Epoch 87/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0154 - val_loss: 0.1615
# Epoch 88/100
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0152 - val_loss: 0.1624
# Epoch 89/100
# 1/1 [==============================] - 0s 41ms/step - loss: 0.0151 - val_loss: 0.1628
# Epoch 90/100
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0150 - val_loss: 0.1626
# Epoch 91/100
# 1/1 [==============================] - 0s 46ms/step - loss: 0.0149 - val_loss: 0.1619
# Epoch 92/100
# 1/1 [==============================] - 0s 77ms/step - loss: 0.0148 - val_loss: 0.1610
# Epoch 93/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0147 - val_loss: 0.1600
# Epoch 94/100
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0146 - val_loss: 0.1593
# Epoch 95/100
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0145 - val_loss: 0.1588
# Epoch 96/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0145 - val_loss: 0.1587
# Epoch 97/100
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0144 - val_loss: 0.1588
# Epoch 98/100
# 1/1 [==============================] - 0s 40ms/step - loss: 0.0143 - val_loss: 0.1591
# Epoch 99/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0142 - val_loss: 0.1593
# Epoch 100/100
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0141 - val_loss: 0.1593
# Predicting back on shot 1/5
# 1/1 [==============================] - 1s 705ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# Shape of predicted_sequences: (33, 5)
# Back prediction for shot 1 completed.
# Predicting back on shot 2/5
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 45ms/step
# C:\Users\weicheng\AppData\Local\Temp\ipykernel_26120\3814716982.py:142: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   output_df_2 = output_df[dropping_status_columns].applymap(lambda x: 1 if abs(x) > 0.5 else 0)
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# Shape of predicted_sequences: (33, 5)
# Back prediction for shot 2 completed.
# Predicting back on shot 3/5
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - ETA: 0s
# C:\Users\weicheng\AppData\Local\Temp\ipykernel_26120\3814716982.py:142: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   output_df_2 = output_df[dropping_status_columns].applymap(lambda x: 1 if abs(x) > 0.5 else 0)
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# Shape of predicted_sequences: (33, 5)
# Back prediction for shot 3 completed.
# Predicting back on shot 4/5
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - ETA: 0s
# C:\Users\weicheng\AppData\Local\Temp\ipykernel_26120\3814716982.py:142: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   output_df_2 = output_df[dropping_status_columns].applymap(lambda x: 1 if abs(x) > 0.5 else 0)
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 20ms/step
# Shape of predicted_sequences: (33, 5)
# Back prediction for shot 4 completed.
# Predicting back on shot 5/5
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - ETA: 0s
# C:\Users\weicheng\AppData\Local\Temp\ipykernel_26120\3814716982.py:142: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   output_df_2 = output_df[dropping_status_columns].applymap(lambda x: 1 if abs(x) > 0.5 else 0)
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# Shape of predicted_sequences: (33, 5)
# Back prediction for shot 5 completed.
# C:\Users\weicheng\AppData\Local\Temp\ipykernel_26120\3814716982.py:142: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   output_df_2 = output_df[dropping_status_columns].applymap(lambda x: 1 if abs(x) > 0.5 else 0)
